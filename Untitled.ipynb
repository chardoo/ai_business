# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score, calinski_harabasz_score
import warnings

# %matplotlib inline
raw_data = pd.read_csv('sales_data_sample.csv', encoding = 'unicode_escape')
raw_data.drop(['ORDERNUMBER' ], axis=1, inplace=True)
raw_data.drop(['ADDRESSLINE2'], axis=1, inplace=True)
raw_data['ORDERDATE'] = pd.to_datetime(raw_data['ORDERDATE'], errors='coerce')

# %%
# ordernumber was drop because it useless 
# the address2 is useless becuase it mostly emptgy and

# %%
raw_data.head()
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  ORDERDATE   STATUS  \
# 0               39     100.00                2  4808.31 2003-01-10  Shipped
# 1               33      99.66                6  3288.78 2003-03-25  Shipped
# 2               32     100.00                1  3254.72 2003-05-21  Shipped
# 3               31     100.00                7  3184.94 2003-07-16  Shipped
# 4               50     100.00                4  5907.50 2003-09-12  Shipped
#
#    QTR_ID  MONTH_ID  YEAR_ID   PRODUCTLINE  ...            PHONE  \
# 0       1         1     2003  Vintage Cars  ...       2125551500
# 1       1         3     2003  Vintage Cars  ...       6505555787
# 2       2         5     2003  Vintage Cars  ...     03 9520 4555
# 3       3         7     2003  Vintage Cars  ...  +61 2 9495 8555
# 4       3         9     2003  Vintage Cars  ...       4155554312
#
#                               ADDRESSLINE1           CITY     STATE  \
# 0                        2678 Kingston Rd.            NYC        NY
# 1                5557 North Pendale Street  San Francisco        CA
# 2                        636 St Kilda Road      Melbourne  Victoria
# 3  Monitor Money Building, 815 Pacific Hwy      Chatswood       NSW
# 4                        2793 Furth Circle       Brisbane        CA
#
#   POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      10022        USA       NaN           Frick          Michael   Medium
# 1        NaN        USA       NaN          Murphy            Julie   Medium
# 2       3004  Australia      APAC        Ferguson            Peter   Medium
# 3       2067  Australia      APAC          Huxley           Adrian   Medium
# 4      94217        USA       NaN          Taylor              Sue   Medium
#
# [5 rows x 23 columns]

# %%
# Dealsize need to be encoded to numeric value using one hot encoding 

# Time-based Campaigns:  ORDERDATE to analyze the best times for promotions, such as holidays or end-of-quarter sales.
# Targeted Offers Based on Order Size:  QUANTITYORDERED and SALES to identify customers who may be interested in bulk buying or those who can be upsold.
# Price Segmentation: Tailor PRICEEACH to design price-based promotions, like discounts on high-end products or special offers for budget-conscious customers.
# Deal Size Targeting: Develop exclusive campaigns or loyalty programs for customers making Medium or Large orders.
# Product Line-Focused Campaigns: Promote top-performing product lines and offer discounts or incentives for underperforming products to balance sales.

# Normalize the data using StandardScaler

# %%
df_onehot_size = pd.get_dummies(raw_data["DEALSIZE"], prefix="Size")
df_onehot_productLine = pd.get_dummies(raw_data["PRODUCTLINE"], prefix="ProductLine")
label_encoder = LabelEncoder()
raw_data['PRODUCTLINE_Encoded'] = label_encoder.fit_transform(raw_data['PRODUCTLINE'])

raw_data = pd.concat([raw_data, df_onehot_size, df_onehot_productLine], axis=1)
raw_data


feature_data = raw_data[['MONTH_ID', 'YEAR_ID', 'QUANTITYORDERED',  'PRICEEACH', 'Size_Medium', 'Size_Small',  'Size_Large', 
                         'PRODUCTLINE_Encoded'
                        #  'ProductLine_Planes', 'ProductLine_Ships', 'ProductLine_Trains',
                        #     'ProductLine_Trucks and Buses', 'ProductLine_Vintage Cars',
                        #     'ProductLine_Classic Cars',
                        #  'ProductLine_Motorcycles' 
                         
                         ]]
feature_data
# Out:
#       MONTH_ID  YEAR_ID  QUANTITYORDERED  PRICEEACH  Size_Medium  Size_Small  \
# 0            1     2003               39     100.00         True       False
# 1            3     2003               33      99.66         True       False
# 2            5     2003               32     100.00         True       False
# 3            7     2003               31     100.00         True       False
# 4            9     2003               50     100.00         True       False
# ...        ...      ...              ...        ...          ...         ...
# 2818        12     2004               27     100.00         True       False
# 2819         1     2005               34     100.00         True       False
# 2820         2     2005               34      54.84        False        True
# 2821         5     2005               34     100.00         True       False
# 2822         5     2005               46      80.92         True       False
#
#       Size_Large  PRODUCTLINE_Encoded
# 0          False                    6
# 1          False                    6
# 2          False                    6
# 3          False                    6
# 4          False                    6
# ...          ...                  ...
# 2818       False                    0
# 2819       False                    0
# 2820       False                    0
# 2821       False                    0
# 2822       False                    0
#
# [2823 rows x 8 columns]

# %%
# Convert the scaled features into a DataFrame for easier inspection
scaler = StandardScaler()
scaled_features = scaler.fit_transform(feature_data)

scaled_data = pd.DataFrame(scaled_features, columns=feature_data.columns)

# %%
wcss = []
k_range = range(1, 11)  # Test k from 1 to 10

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)

# Plot the elbow curve
plt.figure(figsize=(10, 6))
plt.plot(k_range, wcss, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of clusters (k)')
plt.ylabel('WCSS')
plt.show()

# %%
optimal_k = 3  
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
cluster_labels = kmeans.fit_predict(scaled_data)

scaled_data['Cluster'] = cluster_labels
scaled_data
# Out:
#       MONTH_ID   YEAR_ID  QUANTITYORDERED  PRICEEACH  Size_Medium  Size_Small  \
# 0    -1.666433 -1.165170         0.401161   0.810158     1.019676    -0.91210
# 1    -1.119385 -1.165170        -0.214874   0.793302     1.019676    -0.91210
# 2    -0.572337 -1.165170        -0.317546   0.810158     1.019676    -0.91210
# 3    -0.025289 -1.165170        -0.420218   0.810158     1.019676    -0.91210
# 4     0.521759 -1.165170         1.530557   0.810158     1.019676    -0.91210
# ...        ...       ...              ...        ...          ...         ...
# 2818  1.342332  0.264328        -0.830908   0.810158     1.019676    -0.91210
# 2819 -1.666433  1.693826        -0.112201   0.810158     1.019676    -0.91210
# 2820 -1.392909  1.693826        -0.112201  -1.428733    -0.980703     1.09637
# 2821 -0.572337  1.693826        -0.112201   0.810158     1.019676    -0.91210
# 2822 -0.572337  1.693826         1.119867  -0.135768     1.019676    -0.91210
#
#       Size_Large  PRODUCTLINE_Encoded  Cluster
# 0      -0.242672             1.445293        1
# 1      -0.242672             1.445293        1
# 2      -0.242672             1.445293        1
# 3      -0.242672             1.445293        1
# 4      -0.242672             1.445293        1
# ...          ...                  ...      ...
# 2818   -0.242672            -1.043056        1
# 2819   -0.242672            -1.043056        1
# 2820   -0.242672            -1.043056        0
# 2821   -0.242672            -1.043056        1
# 2822   -0.242672            -1.043056        1
#
# [2823 rows x 9 columns]

# %%
if scaled_data.shape[1] > 3:  # If more than 2 features + cluster column
    pca = PCA(n_components=2)
    pca_data = pca.fit_transform(scaled_data.drop('Cluster', axis=1))
    
    component_df = pd.DataFrame(
    pca.components_.T,
    columns=['PC1', 'PC2'],
    index=feature_data.columns
    )
    print("Principal Component Loadings:")
    print(component_df.round(3))
    print(f"\nPC1 explains {pca.explained_variance_ratio_[0]:.1%} of variance")
    print(f"PC2 explains {pca.explained_variance_ratio_[1]:.1%} of variance")
    plt.figure(figsize=(10, 8))
    scatter = plt.scatter(pca_data[:, 0], pca_data[:, 1], c=cluster_labels, cmap='viridis')
    plt.colorbar(scatter)
    plt.title('K-Means Clustering Results (PCA)')
    plt.xlabel('First Principal Component')
    plt.ylabel('Second Principal Component')
    plt.show()
# Out:
# Principal Component Loadings:
#                        PC1    PC2
# MONTH_ID             0.012 -0.647
# YEAR_ID             -0.014  0.660
# QUANTITYORDERED     -0.288  0.230
# PRICEEACH           -0.472 -0.079
# Size_Medium         -0.547 -0.132
# Size_Small           0.606  0.013
# Size_Large          -0.123  0.261
# PRODUCTLINE_Encoded  0.111 -0.019
#
# PC1 explains 32.4% of variance
# PC2 explains 18.3% of variance

# %%
print("=== CLUSTER ANALYSIS ===\n")

# Check cluster sizes
unique, counts = np.unique(cluster_labels, return_counts=True)
print("Cluster Sizes:")
for i, count in enumerate(counts):
    print(f"Cluster {i}: {count} samples ({count/len(cluster_labels)*100:.1f}%)")

# Add cluster labels to your original data
clustered_data = feature_data.copy()
clustered_data['Cluster'] = cluster_labels

# Examine cluster centers (in original scale)
cluster_centers_scaled = kmeans.cluster_centers_  # Your kmeans model
cluster_centers_original = scaler.inverse_transform(cluster_centers_scaled)

centers_df = pd.DataFrame(cluster_centers_original, columns=feature_data.columns)
centers_df.index = [f'Cluster {i}' for i in range(len(centers_df))]
print("\nCluster Centers (Original Scale):")
print(centers_df.round(2))
# Out:
# === CLUSTER ANALYSIS ===
#
# Cluster Sizes:
# Cluster 0: 1282 samples (45.4%)
# Cluster 1: 1384 samples (49.0%)
# Cluster 2: 157 samples (5.6%)
#
# Cluster Centers (Original Scale):
#            MONTH_ID  YEAR_ID  QUANTITYORDERED  PRICEEACH  Size_Medium  \
# Cluster 0      7.12  2003.81            30.53      69.05         -0.0
# Cluster 1      7.10  2003.81            37.95      95.36          1.0
# Cluster 2      6.77  2003.91            47.22      99.80         -0.0
#
#            Size_Small  Size_Large  PRODUCTLINE_Encoded
# Cluster 0         1.0        -0.0                 2.81
# Cluster 1         0.0        -0.0                 2.37
# Cluster 2         0.0         1.0                 1.40
